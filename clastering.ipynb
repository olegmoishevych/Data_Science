# %%
import numpy as np
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
matplotlib.rc('font', size=18)

# %%
#загружаем данные 
houses = pd.read_csv('../1.4_houses.csv')

# %%
houses.head(6)
# Out:
#    dim_1  dim_2   level   price
# 0     29     28  luxury  2212.0
# 1     28     29  luxury  2203.0
# 2      6      9   basic   254.0
# 3      5      9   basic   242.0
# 4      6      6   basic   195.0
# 5      5      8   basic   200.0

# %%
# Предполагаем, что dim_1 и dim_2 представляют координаты домиков
plt.figure(figsize=(6, 4))
plt.scatter(houses['dim_1'], houses['dim_2'], c='blue', marker='o', edgecolor='black')

# Настройка заголовков и подписей осей
plt.title('Расположение домов')
plt.xlabel('dim_1')
plt.ylabel('dim_2')

# Отображение графика
plt.show()

# %%
from sklearn.cluster import KMeans
#try

# %%
X = houses[['dim_1', 'dim_2']]

# %%
#создаем модель для кластеризации
clust = KMeans(n_clusters=3).fit(X)

# %%
[c1,c2,c3] = clust.cluster_centers_

# %%
# Получаем метки кластеров и центры кластеров
labels = clust.labels_
cluster_centers = clust.cluster_centers_

# Создаем фигуру
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(1, 1, 1)

# Отображаем данные точек с цветами по кластерам
scatter = ax.scatter(X['dim_1'], X['dim_2'], c=labels, cmap='viridis', marker='o', edgecolor='black')

# Отображаем центры кластеров
ax.scatter(cluster_centers[:, 0], cluster_centers[:, 1], s=300, c='red', label='Centroids')

# Настройка заголовков и подписей осей
ax.set_title('Кластеризация домов методом K-средних')
ax.set_xlabel('dim_1')
ax.set_ylabel('dim_2')
ax.legend()

# Отображение графика
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5 ax = fig.add_subplot(1, 1, 1)
#       7 # Отображаем данные точек с цветами по кластерам
# ----> 8 scatter = ax.scatter(X['dim_1'], X['dim_2'], c=labels, cmap='viridis', marker='o', edgecolor='black')
#      10 # Отображаем центры кластеров
#      11 ax.scatter(cluster_centers[:, 0], cluster_centers[:, 1], s=300, c='red', label='Centroids')
#
# File ~/Desktop/Projects/Data_Science/lesson_4/venv/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
# ...
